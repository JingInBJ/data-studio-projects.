# 2002         13.4454  16.0647  13.5851  19.9774  16.7527  20.8837  11.3805
# 2003         13.3161  15.0159  13.0939  20.0616  16.1002  21.1104  10.7029
# 2004         13.1802  14.6593  12.6847  20.2797  15.8898  21.3325  10.1579
# 2005         12.9931  13.7372  12.2493  20.3141  15.5384  21.6449   9.9032
# 2006         12.9941  12.9416  11.7272  20.9283  15.5951  21.6139  9.44995
# 2007         12.7825  12.2484  11.6297  21.0934   15.945   22.076  9.02668
# ...

# %%
df_ratio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, 1997 to 2018
# Data columns (total 7 columns):
# US         22 non-null object
# Canada     19 non-null object
# France     22 non-null object
# Germany    22 non-null object
# Italy      22 non-null object
# Japan      21 non-null object
# UK         22 non-null object
# dtypes: object(7)
# memory usage: 1.4+ KB

# %%
df_ratio['US']=df_ratio['US'].astype('float').round(1)
df_ratio['Canada']=df_ratio['Canada'].astype('float').round(1)
df_ratio['France']=df_ratio['France'].astype('float').round(1)
df_ratio['Germany']=df_ratio['Germany'].astype('float').round(1)
df_ratio['Italy']=df_ratio['Italy'].astype('float').round(1)
df_ratio['Japan']=df_ratio['Japan'].astype('float').round(1)
df_ratio['UK']=df_ratio['UK'].astype('float').round(1)
#应该有更简便的方法，一次性清理所有的国家列

# %%
df_ratio
# Out:
# CountryName    US  Canada  France  Germany  Italy  Japan    UK
# 1997         16.1    16.3    14.7     20.3   18.3   23.4  15.3
# 1998         15.8    16.5    14.7     20.5   18.3   22.9  14.5
# 1999         15.4    17.4    14.4     20.1   17.7   22.5  13.6
# 2000         15.1    17.4    14.5     20.7   17.5   22.6  13.0
# 2001         13.9    16.4    14.0     20.5   17.1   21.3  12.1
# 2002         13.4    16.1    13.6     20.0   16.8   20.9  11.4
# 2003         13.3    15.0    13.1     20.1   16.1   21.1  10.7
# 2004         13.2    14.7    12.7     20.3   15.9   21.3  10.2
# 2005         13.0    13.7    12.2     20.3   15.5   21.6   9.9
# 2006         13.0    12.9    11.7     20.9   15.6   21.6   9.4
# 2007         12.8    12.2    11.6     21.1   15.9   22.1   9.0
# 2008         12.3    10.9    11.1     20.2   15.4   21.4   9.0
# 2009         11.7    10.4    10.6     17.9   13.7   19.1   8.7
# 2010         11.9    10.4    10.3     20.0   14.2   20.8   8.9
# ...

# %%
fig, ax = plt.subplots(figsize=(20, 10))


plt.title("G7's Manufacturing output(% of GDP)")
ax.title.set_fontsize(20)

ax.plot(df_ratio.index,
        df_ratio["US"],
        color = "red",
        linewidth=5.0)

ax.plot(df_ratio.index,
        df_ratio["Canada"],
        color = "#fdbf6f",
        linewidth=5.0)

ax.plot(df_ratio.index,
        df_ratio["France"],
        color = "#a6cee3",
        linewidth=5.0)

ax.plot(df_ratio.index,
        df_ratio["Germany"],
        color = "#bebada",
        linewidth=5.0)

ax.plot(df_ratio.index,
        df_ratio["Italy"],
        color = "#80b1d3",
        linewidth=5.0)

ax.plot(df_ratio.index,
        df_ratio["Japan"],
        color = "#ffff33",
        linewidth=5.0)

ax.plot(df_ratio.index,
        df_ratio["UK"],
        color = "#fccde5",
        linewidth=5.0)


labels = list(['US','Canada','France','Germany','Italy','Japan','UK'])
plt.legend(labels, loc='bottom left')

plt.savefig("G7.pdf", transparent=False)
# Out:
# /Users/jingyang/anaconda3/lib/python3.7/site-packages/matplotlib/legend.py:497: UserWarning: Unrecognized location "bottom left". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
df_value = pd.read_csv('3-NewOrderValue.csv')
df_value.head()
# Out:
#          DATE    AMTMNO
# 0  1992-02-01  223500.0
# 1  1992-03-01  233732.0
# 2  1992-04-01  238173.0
# 3  1992-05-01  241916.0
# 4  1992-06-01  240660.0

# %%
df_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 2 columns):
# DATE      328 non-null object
# AMTMNO    328 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 5.2+ KB

# %%
df_value['DATE']=pd.to_datetime(df_value['DATE'])

# %%
df_value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 2 columns):
# DATE      328 non-null datetime64[ns]
# AMTMNO    328 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.2 KB

# %%
#如何选取1997年以后的？
